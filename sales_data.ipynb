# %%
#import needed libraries
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Sales Data.xlsx')
df.tail(10)
# Out:
#       Row ID    Date  Country Product ID  Shop  Gender Size (US)  \
# 14967      ?       ?        ?          ?     ?       ?         ?
# 14968      ?     Jan  Germany       2156  GER1  Female       4.5
# 14969      ?     Feb  Germany       2156  GER1  Female       4.5
# 14970      ?   March  Germany       2156  GER1  Female       4.5
# 14971      ?  August  Germany       2156  GER1  Female       4.5
# 14972      ?       ?  Germany       2156  GER1  Female       6.5
# 14973      ?       ?  Germany       2156  GER1  Female       6.5
# 14974      ?       ?  Germany       2156  GER1  Female       6.5
# 14975      ?       ?  Germany       2156  GER1  Female       6.5
# 14976      ?       ?  Germany       2156  GER1  Female       6.5
#
#       Size (Europe) Size (UK) Unit Price Discount  Year Month Sales Price
# 14967             ?         ?          ?        ?     ?     ?           ?
# 14968            35       2.5        179        0   NaN   NaN         179
# ...

# %%
# median

df['Sales Price'].describe()
df['Size (US)'].describe()


# merging, outlier, mainly data transformation--> removing duplicates, missing values treatment, replacing values, 
# numerical values to categorical
# plots
# random sampling to remove bias and to keep
# Out:
# count    14967.000000
# mean         9.195630
# std          1.511719
# min          4.500000
# 25%          8.000000
# 50%          9.000000
# 75%         10.000000
# max         15.000000
# Name: Size (US), dtype: float64
